# %%
adi = "Gönenç "
ikinci_adi = "Arda  "
soyadi = "Kökdemir"

# %%
for i in range(1,100):
    print("{} inci satır: {}".format(i, adi))
# Out:
# 1 inci satır: Gönenç
# 2 inci satır: Gönenç
# 3 inci satır: Gönenç
# 4 inci satır: Gönenç
# 5 inci satır: Gönenç
# 6 inci satır: Gönenç
# 7 inci satır: Gönenç
# 8 inci satır: Gönenç
# 9 inci satır: Gönenç
# 10 inci satır: Gönenç
# 11 inci satır: Gönenç
# 12 inci satır: Gönenç
# 13 inci satır: Gönenç
# 14 inci satır: Gönenç
# 15 inci satır: Gönenç
# 16 inci satır: Gönenç
# 17 inci satır: Gönenç
# 18 inci satır: Gönenç
# 19 inci satır: Gönenç
# 20 inci satır: Gönenç
# 21 inci satır: Gönenç
# 22 inci satır: Gönenç
# 23 inci satır: Gönenç
# 24 inci satır: Gönenç
# 25 inci satır: Gönenç
# 26 inci satır: Gönenç
# 27 inci satır: Gönenç
# 28 inci satır: Gönenç
# 29 inci satır: Gönenç
# 30 inci satır: Gönenç
# 31 inci satır: Gönenç
# 32 inci satır: Gönenç
# 33 inci satır: Gönenç
# 34 inci satır: Gönenç
# 35 inci satır: Gönenç
# 36 inci satır: Gönenç
# 37 inci satır: Gönenç
# 38 inci satır: Gönenç
# 39 inci satır: Gönenç
# 40 inci satır: Gönenç
# 41 inci satır: Gönenç
# 42 inci satır: Gönenç
# ...
